# %%
import torch
from micro_diffusion.models.utils import UniversalTokenizer, UniversalTextEncoder

captions = [
      "Nature in silhouette of an owl",
      "cyberpunk panda ",
      "majestic knight in shining armor",
      "waterfall dragon",
      "Robot in forest",
      "Shield maiden with wings",
      "a shadowy land of ghosts and specters",
      "woman with red cape long hair",
      "galaxy volcano explosion",
      "sage crystal orb",
]


tokenizer = UniversalTokenizer ('openclip:hf-hub:apple/DFN5B-CLIP-ViT-H-14-378')
clip = UniversalTextEncoder ("openclip:hf-hub:apple/DFN5B-CLIP-ViT-H-14-378", weights_dtype="bfloat16", pretrained=True).to('cuda')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#       4 captions = [
#       5       "Nature in silhouette of an owl",
#       6       "cyberpunk panda ",
#    (...)
#      14       "sage crystal orb",
#      15 ]
#      18 tokenizer = UniversalTokenizer ('openclip:hf-hub:apple/DFN5B-CLIP-ViT-H-14-378')
# ---> 19 clip = UniversalTextEncoder ("openclip:hf-hub:apple/DFN5B-CLIP-ViT-H-14-378", weights_dtype="bfloat16", pretrained=True).to('cuda')
#
# File E:\Research\DaVinci\micro_diffusion\models\utils.py:110, in UniversalTextEncoder.__init__(self, name, weights_dtype, pretrained)
#     107 if self.name.startswith("openclip:"):
#     108     assert pretrained, f"load default pretrained model from openclip"
#     109     self.encoder = openclip_text_encoder(
# --> 110         open_clip.create_model_and_transforms(name.lstrip('openclip:'))[0],
#     111         torch_dtype= DATA_TYPES[weights_dtype]
#     112     )
#     113 elif self.name == "DeepFloyd/t5-v1_1-xxl":
#     114     self.encoder = T5EncoderModel.from_pretrained (
#     115         name,
#     116         torch_dtype=DATA_TYPES[weights_dtype],
#     117         pretrained = pretrained
#     118     )
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\open_clip\factory.py:384, in create_model_and_transforms(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, image_mean, image_std, image_interpolation, image_resize_mode, aug_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, **model_kwargs)
#     360 def create_model_and_transforms(
#     361         model_name: str,
#     362         pretrained: Optional[str] = None,
#    (...)
#     379         **model_kwargs,
#     380 ):
#     381     force_preprocess_cfg = merge_preprocess_kwargs(
#     382         {}, mean=image_mean, std=image_std, interpolation=image_interpolation, resize_mode=image_resize_mode)
# --> 384     model = create_model(
#     385         model_name,
#     386         pretrained,
#     387         precision=precision,
#     388         device=device,
#     389         jit=jit,
#     390         force_quick_gelu=force_quick_gelu,
#     391         force_custom_text=force_custom_text,
#     392         force_patch_dropout=force_patch_dropout,
#     393         force_image_size=force_image_size,
#     394         force_preprocess_cfg=force_preprocess_cfg,
#     395         pretrained_image=pretrained_image,
#     396         pretrained_hf=pretrained_hf,
#     397         cache_dir=cache_dir,
#     398         output_dict=output_dict,
#     399         **model_kwargs,
#     400     )
#     402     pp_cfg = PreprocessCfg(**model.visual.preprocess_cfg)
#     404     preprocess_train = image_transform_v2(
#     405         pp_cfg,
#     406         is_train=True,
#     407         aug_cfg=aug_cfg,
#     408     )
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\open_clip\factory.py:188, in create_model(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, force_preprocess_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, require_pretrained, **model_kwargs)
#     186 if has_hf_hub_prefix:
#     187     model_id = model_name[len(HF_HUB_PREFIX):]
# --> 188     checkpoint_path = download_pretrained_from_hf(model_id, cache_dir=cache_dir)
#     189     config = _get_hf_config(model_id, cache_dir)
#     190     preprocess_cfg = merge_preprocess_dict(preprocess_cfg, config['preprocess_cfg'])
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\open_clip\pretrained.py:552, in download_pretrained_from_hf(model_id, filename, revision, cache_dir)
#     545 def download_pretrained_from_hf(
#     546         model_id: str,
#     547         filename: str = 'open_clip_pytorch_model.bin',
#     548         revision=None,
#     549         cache_dir: Union[str, None] = None,
#     550 ):
#     551     has_hf_hub(True)
# --> 552     cached_file = hf_hub_download(model_id, filename, revision=revision, cache_dir=cache_dir)
#     553     return cached_file
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\huggingface_hub\file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#    (...)
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=hf_headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\huggingface_hub\file_download.py:1011, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1009 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1010 with WeakFileLock(lock_path):
# -> 1011     _download_to_tmp_and_move(
#    1012         incomplete_path=Path(blob_path + ".incomplete"),
#    1013         destination_path=Path(blob_path),
#    1014         url_to_download=url_to_download,
#    1015         proxies=proxies,
#    1016         headers=headers,
#    1017         expected_size=expected_size,
#    1018         filename=filename,
#    1019         force_download=force_download,
#    1020     )
#    1021     if not os.path.exists(pointer_path):
#    1022         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\huggingface_hub\file_download.py:1547, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1544         _check_disk_space(expected_size, incomplete_path.parent)
#    1545         _check_disk_space(expected_size, destination_path.parent)
# -> 1547     http_get(
#    1548         url_to_download,
#    1549         f,
#    1550         proxies=proxies,
#    1551         resume_size=resume_size,
#    1552         headers=headers,
#    1553         expected_size=expected_size,
#    1554     )
#    1556 logger.info(f"Download complete. Moving file to {destination_path}")
#    1557 _chmod_and_move(incomplete_path, destination_path)
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\huggingface_hub\file_download.py:454, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 new_resume_size = resume_size
#     453 try:
# --> 454     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     455         if chunk:  # filter out keep-alive new chunks
#     456             progress.update(len(chunk))
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\http\client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\http\client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Zen\miniconda3\envs\tr\lib\ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
latents = (clip.encode(tokenizer.tokenize(captions)['caption_idx'].to('cuda'))[0])

# %%
latents.shape
save_dir = "./caption_latents.pt"
torch.save(latents.cpu(), save_dir)

# %%
a = torch.load(save_dir)

# %%
type(a)

# %%
type((tokenizer.tokenize(captions))['caption_idx'])
